# %% [markdown]
# <a href="https://colab.research.google.com/github/ranae-jones/-git-config---global-user.name-Ranae/blob/main/Copy_of_Astronomy_starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, accuracy_score

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d266c893-dfe6-466c-97bf-32233085977e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d266c893-dfe6-466c-97bf-32233085977e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
metrics.ConfusionMatrixDisplay.from_predictions(y_test, pred_unscaled, display_labels = model_unscaled.classes_)

plt.show()

# %%
df = pd.read_csv('Meteorite_Landings (4).csv')
df.head()

# %%
How accurately can we predict the trajectory of a meteor using historical meteor path data?

# %%
plt.plot(scores_5, label = '5NN')
plt.plot([scores_5.mean() for i in range(10)], label = 'average')

plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Physical constants
g = 9.81              # gravity (m/s^2)
rho = 1.225           # air density at sea level (kg/m^3)
Cd = 1.3              # drag coefficient (spherical approximation)
A = 1.0               # cross-sectional area (m^2)
m = 1000.0            # mass of meteor (kg)

# Initial conditions (can be based on historical meteor data)
initial_pos = np.array([0.0, 100000.0])      # position [x, y] in meters
initial_vel = np.array([5000.0, -8000.0])    # velocity [vx, vy] in m/s

# Time setup
dt = 0.1              # time step (seconds)
t_max = 200           # total simulation time (seconds)
steps = int(t_max / dt)

# Storage arrays
positions = np.zeros((steps, 2))
velocities = np.zeros((steps, 2))
times = np.zeros(steps)

positions[0] = initial_pos
velocities[0] = initial_vel

# Euler integration loop
for i in range(1, steps):
    v = np.linalg.norm(velocities[i - 1])
    drag_force = -0.5 * rho * Cd * A * v * velocities[i - 1]
    gravity = np.array([0.0, -m * g])
    total_force = drag_force + gravity
    acceleration = total_force / m

    velocities[i] = velocities[i - 1] + acceleration * dt
    positions[i] = positions[i - 1] + velocities[i] * dt
    times[i] = times[i - 1] + dt

    if positions[i][1] <= 0:
        # Cut arrays at impact point
        positions = positions[:i+1]
        velocities = velocities[:i+1]
        times = times[:i+1]
        break

# Compute speed and altitude
speed = np.linalg.norm(velocities, axis=1)
altitude = positions[:, 1] / 1000  # convert to km
distance = positions[:, 0] / 1000  # convert to km

# --- Plotting ---
plt.figure(figsize=(14, 10))

# 1. Trajectory
plt.subplot(3, 1, 1)
plt.plot(distance, altitude, color='navy')
plt.title('Meteor Trajectory')
plt.xlabel('Horizontal Distance (km)')
plt.ylabel('Altitude (km)')
plt.grid(True)

# 2. Speed vs Time
plt.subplot(3, 1, 2)
plt.plot(times, speed, color='darkred')
plt.title('Speed vs Time')
plt.xlabel('Time (s)')
plt.ylabel('Speed (m/s)')
plt.grid(True)

# 3. Altitude vs Time
plt.subplot(3, 1, 3)
plt.plot(times, altitude, color='darkgreen')
plt.title('Altitude vs Time')
plt.xlabel('Time (s)')
plt.ylabel('Altitude (km)')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
plt.plot(scores_1, label = '1NN')
plt.plot(scores_5, label = '5NN')
plt.plot(scores_11, label = '11NN')
plt.plot(scores_99, label = '99NN')

plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
plt.figure(figsize=(8, 8))


plt.scatter(y_test, pred)
plt.plot([0, 6], [0, 6], '--k', label="Correct prediction")


plt.xlabel('True Price')
plt.ylabel('Predicted Price')
plt.title("Real vs. Predicted Price")

plt.axis('tight')
plt.legend()
plt.tight_layout()

# %%
'Meteorite_Landings (4).csv')
df_metors = pd.read_csv(file, sep='\t')
display(df_metors.head())

# %%
obs = meteor.load_observations("multistation_data.csv")
traj = trajectory.estimate_trajectory(obs)
print(f"Predicted trajectory position: {traj.position}")
print(f"Prediction uncertainty: {traj.uncertainty}")

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
g = 9.81  # gravity [m/s^2]
rho = 1.225  # air density at sea level [kg/m^3]
Cd = 1.3  # drag coefficient (spherical)
A = 1.0  # cross-sectional area [m^2]
m = 1000.0  # mass of meteor [kg]

# Initial Conditions (example: entry from historical data)
initial_pos = np.array([0, 100000])  # [x, y] in meters
initial_vel = np.array([5000, -8000])  # [vx, vy] in m/s

# Time setup
dt = 0.1  # time step
t_max = 200  # max time
steps = int(t_max / dt)

# Initialize arrays
positions = np.zeros((steps, 2))
velocities = np.zeros((steps, 2))
positions[0] = initial_pos
velocities[0] = initial_vel

# Numerical Integration (Euler Method)
for i in range(1, steps):
    v = np.linalg.norm(velocities[i-1])
    drag_force = -0.5 * rho * Cd * A * v * velocities[i-1]
    gravity = np.array([0, -m * g])
    total_force = drag_force + gravity
    acceleration = total_force / m

    velocities[i] = velocities[i-1] + acceleration * dt
    positions[i] = positions[i-1] + velocities[i] * dt

    # Stop if meteor hits the ground
    if positions[i][1] <= 0:
        positions = positions[:i+1]
        break

# Plot
plt.plot(positions[:, 0] / 1000, positions[:, 1] / 1000)
plt.title('Predicted Meteor Trajectory')
plt.xlabel('Horizontal Distance (km)')
plt.ylabel('Altitude (km)')
plt.grid(True)
plt.show()
